# %%
import numpy as np
import pandas as pd
import os, sys
import json
import pprint

# %%
dataset_name = 'soybean_disease'
inp_fname = 'soybean_disease.csv'

# %%
input_dir = './raw'
output_dir = './processed'

outp_fname = os.path.join(output_dir, f'{dataset_name}.csv')
outp_train_fname = os.path.join(output_dir, f'{dataset_name}_train.csv')
outp_test_fname = os.path.join(output_dir, f'{dataset_name}_test.csv')
outp_test_key_fname = os.path.join(output_dir, f'{dataset_name}_test_key.csv')
outp_infer_instances = os.path.join(output_dir, f'{dataset_name}_infer_req.json')

# %% [markdown]
# # Read Data

# %%
cols = [
    'date', 'plant-stand', 'precip', 'temp', 'hail',
    'crop-hist', 'area-damaged', 'severity', 'seed-tmt', 'germination',
    'plant-growth', 'leaves', 'leafspots-halo', 'leafspots-marg', 'leafspot-size',
    'leaf-shred', 'leaf-malf', 'leaf-mild',' stem', 'lodging',
    'stem-cankers', 'canker-lesion', 'fruiting-bodies', 'external decay', 'mycelium',
    'int-discolor', 'sclerotia', 'fruit-pods', 'fruit-spots', 'seed',
    'mold-growth', 'seed-discolor', 'seed-size', 'shriveling', 'roots',
    'class'
]

# %%
data = pd.read_csv(os.path.join(input_dir, inp_fname), header=None, names=cols)
data.head()
# Out:
#       date plant-stand    precip   temp  hail          crop-hist area-damaged  \
# 0  october      normal   gt-norm   norm   yes        same-lst-yr    low-areas
# 1   august      normal   gt-norm   norm   yes   same-lst-two-yrs    scattered
# 2     july      normal   gt-norm   norm   yes        same-lst-yr    scattered
# 3     july      normal   gt-norm   norm   yes        same-lst-yr    scattered
# 4  october      normal   gt-norm   norm   yes   same-lst-two-yrs    scattered
#
#       severity    seed-tmt germination  ... sclerotia fruit-pods fruit-spots  \
# 0   pot-severe        none      90-100  ...    absent       norm         dna
# 1       severe   fungicide       80-89  ...    absent       norm         dna
# 2       severe   fungicide       lt-80  ...    absent       norm         dna
# 3       severe        none       80-89  ...    absent       norm         dna
# 4   pot-severe        none       lt-80  ...    absent       norm         dna
#
#     seed mold-growth seed-discolor seed-size shriveling  roots  \
# 0   norm      absent        absent      norm     absent   norm
# 1   norm      absent        absent      norm     absent   norm
# 2   norm      absent        absent      norm     absent   norm
# 3   norm      absent        absent      norm     absent   norm
# 4   norm      absent        absent      norm     absent   norm
#
#                     class
# 0   diaporthe-stem-canker
# 1   diaporthe-stem-canker
# 2   diaporthe-stem-canker
# 3   diaporthe-stem-canker
# 4   diaporthe-stem-canker
#
# [5 rows x 36 columns]

# %%
id_col = "id"
target_col = "class"

# %% [markdown]
# # Prepare Data

# %%
# replace ? which mean null
data = data.replace(' ?', np.nan)

# %%
data.tail()
# Out:
#       date plant-stand precip      temp hail       crop-hist  area-damaged  \
# 678  april         NaN    NaN       NaN  NaN             NaN   upper-areas
# 679  april   lt-normal    NaN   lt-norm  NaN   diff-lst-year     scattered
# 680   june   lt-normal    NaN   lt-norm  NaN   diff-lst-year     scattered
# 681  april   lt-normal    NaN   lt-norm  NaN     same-lst-yr   whole-field
# 682   june   lt-normal    NaN   lt-norm  NaN     same-lst-yr   whole-field
#
#     severity seed-tmt germination  ... sclerotia fruit-pods fruit-spots seed  \
# 678      NaN      NaN         NaN  ...       NaN        NaN         NaN  NaN
# 679      NaN      NaN         NaN  ...       NaN        dna         NaN  NaN
# 680      NaN      NaN         NaN  ...       NaN        dna         NaN  NaN
# 681      NaN      NaN         NaN  ...       NaN        dna         NaN  NaN
# 682      NaN      NaN         NaN  ...       NaN        dna         NaN  NaN
#
#     mold-growth seed-discolor seed-size shriveling    roots              class
# 678         NaN           NaN       NaN        NaN      NaN       2-4-d-injury
# 679         NaN           NaN       NaN        NaN   rotted   herbicide-injury
# 680         NaN           NaN       NaN        NaN   rotted   herbicide-injury
# 681         NaN           NaN       NaN        NaN   rotted   herbicide-injury
# 682         NaN           NaN       NaN        NaN   rotted   herbicide-injury
#
# [5 rows x 36 columns]

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 683 entries, 0 to 682
# Data columns (total 36 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   date             683 non-null    object
#  1   plant-stand      647 non-null    object
#  2   precip           645 non-null    object
#  3   temp             653 non-null    object
#  4   hail             562 non-null    object
#  5   crop-hist        667 non-null    object
#  6   area-damaged     682 non-null    object
#  7   severity         562 non-null    object
#  8   seed-tmt         562 non-null    object
#  9   germination      571 non-null    object
#  10  plant-growth     667 non-null    object
#  11  leaves           683 non-null    object
#  12  leafspots-halo   599 non-null    object
#  13  leafspots-marg   599 non-null    object
#  14  leafspot-size    599 non-null    object
#  15  leaf-shred       583 non-null    object
#  16  leaf-malf        599 non-null    object
#  17  leaf-mild        575 non-null    object
#  18   stem            667 non-null    object
#  19  lodging          562 non-null    object
#  20  stem-cankers     645 non-null    object
#  21  canker-lesion    645 non-null    object
#  22  fruiting-bodies  577 non-null    object
#  23  external decay   645 non-null    object
#  24  mycelium         645 non-null    object
#  25  int-discolor     645 non-null    object
#  26  sclerotia        645 non-null    object
#  27  fruit-pods       599 non-null    object
#  28  fruit-spots      577 non-null    object
#  29  seed             591 non-null    object
#  30  mold-growth      591 non-null    object
#  31  seed-discolor    577 non-null    object
#  32  seed-size        591 non-null    object
#  33  shriveling       577 non-null    object
#  34  roots            652 non-null    object
#  35  class            683 non-null    object
# dtypes: object(36)
# memory usage: 192.2+ KB

# %% [markdown]
# # Insert Id Column

# %%
# insert Id column 
if id_col not in data.columns:
    N = data.shape[0]
    data.insert(0, id_col, np.arange(N))
    print(data.head())
data[id_col] = data[id_col].astype(str)
# Out:
#    id     date plant-stand    precip   temp  hail          crop-hist  \
# 0   0  october      normal   gt-norm   norm   yes        same-lst-yr
# 1   1   august      normal   gt-norm   norm   yes   same-lst-two-yrs
# 2   2     july      normal   gt-norm   norm   yes        same-lst-yr
# 3   3     july      normal   gt-norm   norm   yes        same-lst-yr
# 4   4  october      normal   gt-norm   norm   yes   same-lst-two-yrs
#
#   area-damaged     severity    seed-tmt  ... sclerotia fruit-pods fruit-spots  \
# 0    low-areas   pot-severe        none  ...    absent       norm         dna
# 1    scattered       severe   fungicide  ...    absent       norm         dna
# 2    scattered       severe   fungicide  ...    absent       norm         dna
# 3    scattered       severe        none  ...    absent       norm         dna
# 4    scattered   pot-severe        none  ...    absent       norm         dna
#
#     seed mold-growth seed-discolor seed-size shriveling  roots  \
# 0   norm      absent        absent      norm     absent   norm
# 1   norm      absent        absent      norm     absent   norm
# 2   norm      absent        absent      norm     absent   norm
# 3   norm      absent        absent      norm     absent   norm
# 4   norm      absent        absent      norm     absent   norm
#
#                     class
# 0   diaporthe-stem-canker
# 1   diaporthe-stem-canker
# 2   diaporthe-stem-canker
# 3   diaporthe-stem-canker
# 4   diaporthe-stem-canker
#
# [5 rows x 37 columns]

# %% [markdown]
# # Shuffle Data

# %%
# shuffle data
data = data.sample(frac=1, random_state=42)
data.head()
# Out:
#       id       date plant-stand    precip      temp  hail          crop-hist  \
# 292  292  september      normal   gt-norm   gt-norm   NaN   same-lst-sev-yrs
# 145  145       june      normal   gt-norm      norm   yes   same-lst-two-yrs
# 211  211     august      normal      norm      norm   yes   same-lst-sev-yrs
# 118  118        may      normal   gt-norm      norm   yes   same-lst-two-yrs
# 302  302          ?         NaN       NaN       NaN   NaN                NaN
#
#      area-damaged     severity    seed-tmt  ... sclerotia fruit-pods  \
# 292   whole-field          NaN         NaN  ...    absent   diseased
# 145   upper-areas   pot-severe        none  ...    absent       norm
# 211   whole-field   pot-severe        none  ...    absent       norm
# 118   whole-field   pot-severe   fungicide  ...    absent       norm
# 302           NaN          NaN         NaN  ...       NaN        NaN
#
#              fruit-spots     seed mold-growth seed-discolor seed-size  \
# 292   brown-w/blk-specks   abnorm     present       present   lt-norm
# 145               absent     norm      absent        absent      norm
# 211               absent     norm      absent        absent      norm
# 118               absent     norm      absent        absent      norm
# 302                  NaN      NaN         NaN           NaN       NaN
#
#     shriveling  roots                         class
# 292    present    NaN   diaporthe-pod-&-stem-blight
# 145     absent   norm                    brown-spot
# 211     absent   norm           alternarialeaf-spot
# 118     absent   norm                    brown-spot
# 302        NaN    NaN                  2-4-d-injury
#
# [5 rows x 37 columns]

# %% [markdown]
# # Save Main Data File

# %%
data.to_csv(outp_fname, index=False)

# %% [markdown]
# # Train Test Split

# %%
from sklearn.model_selection import train_test_split
test_size = 0.1

data_train, data_test = train_test_split(data, test_size=test_size, random_state=42)
print(data_train.shape, data_test.shape)

data_train.to_csv(outp_train_fname, index=False)
data_test.drop(columns=[target_col]).to_csv(outp_test_fname, index=False)
data_test[[id_col, target_col]].to_csv(outp_test_key_fname, index=False)
# Out:
# (614, 37) (69, 37)

# %% [markdown]
# # JSON inference request instance

# %%
instance = data_test.replace({np.nan:None}).drop(columns=[target_col]).reset_index(drop=True).loc[0].to_dict()
infer_req_instance_dict = {  "instances": [ {**instance}, ] }
pprint.pprint(infer_req_instance_dict)
   
with open(outp_infer_instances, 'w', encoding='utf8') as f:
    json.dump(infer_req_instance_dict, f, indent=2, ensure_ascii=False)
# Out:
# {'instances': [{' stem': ' norm',
#                 'area-damaged': ' whole-field',
#                 'canker-lesion': ' dna',
#                 'crop-hist': ' same-lst-yr',
#                 'date': 'june',
#                 'external decay': ' absent',
#                 'fruit-pods': ' norm',
#                 'fruit-spots': ' absent',
#                 'fruiting-bodies': ' absent',
#                 'germination': ' 80-89',
#                 'hail': ' yes',
#                 'id': '446',
#                 'int-discolor': ' none',
#                 'leaf-malf': ' absent',
#                 'leaf-mild': ' absent',
#                 'leaf-shred': ' absent',
#                 'leafspot-size': ' gt-1/8',
#                 'leafspots-halo': ' no-yellow-halos',
#                 'leafspots-marg': ' w-s-marg',
#                 'leaves': ' abnorm',
#                 'lodging': ' yes',
#                 'mold-growth': ' absent',
#                 'mycelium': ' absent',
#                 'plant-growth': ' norm',
#                 'plant-stand': ' normal',
#                 'precip': ' gt-norm',
#                 'roots': ' norm',
#                 'sclerotia': ' absent',
#                 'seed': ' norm',
#                 'seed-discolor': ' absent',
#                 'seed-size': ' norm',
#                 'seed-tmt': ' fungicide',
#                 'severity': ' minor',
#                 'shriveling': ' absent',
#                 'stem-cankers': ' absent',
#                 'temp': ' gt-norm'}]}
